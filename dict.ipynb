# %%
# creating a dictionary
student_info={
    "name": "Alice",
    "age": 20,
    "grade": "A"
}
print(student_info["name"])
print(student_info["age"])
print(student_info["grade"])
# Out:
# Alice
# 20
# A

# %%
employee_details = {
    "employee_id": 12345,
    "name": "John Doe",
    "department": "Sales",
    "salary": 50000,
    "is_full_time": True,
    "education": {
        "sslc": [2009, 85],
        "hsc": [2011, 90],
        "bachelor": [2015, 88]
    }
}

print(employee_details["employee_id"])
print(employee_details["name"])
print(employee_details["department"])
print(employee_details["salary"])
print(employee_details["is_full_time"])
print(employee_details["education"]["bachelor"])
# Out:
# 12345
# John Doe
# Sales
# 50000
# True
# [2015, 88]

# %%
# creating aa empty dictionary
empty_dict ={}

# %%
student_info={"name": "Alice", "age": 20, "grade": "A"}
student_info["city"] = "New York"
print(student_info)
# Out:
# {'name': 'Alice', 'age': 20, 'grade': 'A', 'city': 'New York'}

# %%
student_info={"name": "Alice", "age": 20, "grade": "A"}
student_info["city"] = "New York"
additional_info = {"hobby": "Reading", "year": 2}
student_info.update(additional_info)
print(student_info)
# Out:
# {'name': 'Alice', 'age': 20, 'grade': 'A', 'city': 'New York', 'hobby': 'Reading', 'year': 2}

# %%
student_info={"name": "Alice", "age": 20, "grade": "A"}
key=student_info.keys()
print(
    "keys in dictionary is:",list(key)

)
# Out:
# keys in dictionary is: ['name', 'age', 'grade']

# %%
for i in list(key):
    print(i)
# Out:
# name
# age
# grade

# %%
student_info={
    "name": "Alice",
    "age": 20,
       "grade": "A"
}
sorted_dict = dict(sorted(student_info.items()))
print(sorted_dict)
# Out:
# {'age': 20, 'grade': 'A', 'name': 'Alice'}

# %%
nested_dict = {
    "hr":{"name": "Alice", "age": 30},
    "it":{"name": "Bob", "age": 25},
}
print(nested_dict["hr"])
# Out:
# {'name': 'Alice', 'age': 30}

# %%
words = ["apple", "banana", "cherry"]
word_lengths={word: len(word) for word in words}
print(word_lengths)
# Out:
# {'apple': 5, 'banana': 6, 'cherry': 6}

# %%
keys =["name","age", "city"]
values =["Alice", 30, "New York"]
info_dict={keys[i]: values[i] for i in range(len(keys))}
print(info_dict)
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
#set creation
colors = {"red", "green", "blue"}
print(colors)
# Out:
# {'red', 'green', 'blue'}

# %%
fruits_set={"apple", "banana", "cherry"}
fruits_set=set(["apple", "banana", "cherry"])
print(fruits_set)
# Out:
# {'cherry', 'apple', 'banana'}

# %%
set1={1,2,3}
set2={3,4,5}

union_result=set1 | set2
union_result_result=set1 & set2
print("Union of set 1 and set 2:", union_result)
# Out:
# Union of set 1 and set 2: {1, 2, 3, 4, 5}

# %%
set1={1,2,3}
set2={3,4,5}

union_result=set1 | set2
intersection_result=set1 & set2
print("Union of set 1 and set 2:", union_result)
