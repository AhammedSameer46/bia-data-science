# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
data=pd.read_csv(r"C:\AHAMMED\BIA_DATA_SCIENCE\FIRST_PROJECT\MACHINE_LEARNING\DATASET\customer_segmentation.csv")
import warnings
warnings.filterwarnings('ignore')

# %%
data.head()
# Out:
#        ID  Gender Ever_Married  ...  Family_Size  Var_1 Segmentation
# 0  462809    Male           No  ...          4.0  Cat_4            D
# 1  462643  Female          Yes  ...          3.0  Cat_4            A
# 2  466315  Female          Yes  ...          1.0  Cat_6            B
# 3  461735    Male          Yes  ...          2.0  Cat_6            B
# 4  462669  Female          Yes  ...          6.0  Cat_6            A
#
# [5 rows x 11 columns]

# %%
data.shape
# Out:
# (10695, 11)

# %%
data.size
# Out:
# 117645

# %%
data=data.drop('ID',axis=1)

# %%
data.head()
# Out:
#    Gender Ever_Married  Age  ... Family_Size  Var_1  Segmentation
# 0    Male           No   22  ...         4.0  Cat_4             D
# 1  Female          Yes   38  ...         3.0  Cat_4             A
# 2  Female          Yes   67  ...         1.0  Cat_6             B
# 3    Male          Yes   67  ...         2.0  Cat_6             B
# 4  Female          Yes   40  ...         6.0  Cat_6             A
#
# [5 rows x 10 columns]

# %%
data.describe()
# Out:
#                 Age  Work_Experience   Family_Size
# count  10695.000000      9597.000000  10247.000000
# mean      43.511828         2.619777      2.844052
# std       16.774158         3.390790      1.536427
# min       18.000000         0.000000      1.000000
# 25%       30.000000         0.000000      2.000000
# 50%       41.000000         1.000000      3.000000
# 75%       53.000000         4.000000      4.000000
# max       89.000000        14.000000      9.000000

# %%
data.describe(include="O")
# Out:
#        Gender Ever_Married Graduated  ... Spending_Score  Var_1 Segmentation
# count   10695        10505     10593  ...          10695  10587         8068
# unique      2            2         2  ...              3      7            4
# top      Male          Yes       Yes  ...            Low  Cat_6            D
# freq     5841         6163      6570  ...           6494   6910         2268
#
# [4 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# Gender                0
# Ever_Married        190
# Age                   0
# Graduated           102
# Profession          162
# Work_Experience    1098
# Spending_Score        0
# Family_Size         448
# Var_1               108
# Segmentation       2627
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(492)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10695 entries, 0 to 10694
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           10695 non-null  str
#  1   Ever_Married     10505 non-null  str
#  2   Age              10695 non-null  int64
#  3   Graduated        10593 non-null  str
#  4   Profession       10533 non-null  str
#  5   Work_Experience  9597 non-null   float64
#  6   Spending_Score   10695 non-null  str
#  7   Family_Size      10247 non-null  float64
#  8   Var_1            10587 non-null  str
#  9   Segmentation     8068 non-null   str
# dtypes: float64(2), int64(1), str(7)
# memory usage: 1.1 MB

# %%
categorical_col=data.select_dtypes(include=['object']).columns
numerical_col=data.select_dtypes(include=['int64','float64']).columns
print("Categorical columns:",categorical_col)
print("Numerical columns:",numerical_col)
# Out:
# Categorical columns: Index(['Gender', 'Ever_Married', 'Graduated', 'Profession', 'Spending_Score',
#        'Var_1', 'Segmentation'],
#       dtype='str')
# Numerical columns: Index(['Age', 'Work_Experience', 'Family_Size'], dtype='str')

# %%
for col in numerical_col:
    data[col]=data[col].fillna(data[col].median())

# %%
for col in categorical_col:
    data[col]=data[col].fillna(data[col].mode()[0])

# %%
data.isnull().sum()
# Out:
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Profession         0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# Var_1              0
# Segmentation       0
# dtype: int64

# %%
label_encoding_dict={}
for col in categorical_col:
    le=LabelEncoder()
    data[col]=le.fit_transform(data[col])
    label_encoding_dict[col]=le

# %%
data.head()
# Out:
#    Gender  Ever_Married  Age  ...  Family_Size  Var_1  Segmentation
# 0       1             0   22  ...          4.0      3             3
# 1       0             1   38  ...          3.0      3             0
# 2       0             1   67  ...          1.0      5             1
# 3       1             1   67  ...          2.0      5             1
# 4       0             1   40  ...          6.0      5             0
#
# [5 rows x 10 columns]

# %%
data["Age"]
# Out:
# 0        22
# 1        38
# 2        67
# 3        67
# 4        40
#          ..
# 10690    29
# 10691    35
# 10692    53
# 10693    47
# 10694    43
# Name: Age, Length: 10695, dtype: int64

# %%
scaler=StandardScaler()
scaler.fit_transform(data[["Age"]])
# Out:
# array([[-1.28249856],
#        [-0.3286058 ],
#        [ 1.40032483],
#        ...,
#        [ 0.56566866],
#        [ 0.20795888],
#        [-0.03051431]], shape=(10695, 1))

# %%
scaler_dict={}
for col in numerical_col:
    scaler=StandardScaler()
    data[col]=scaler.fit_transform(data[[col]])
    scaler_dict[col]=scaler

# %%
kmeans=KMeans(n_clusters=5,random_state=42)
kmeans.fit(data)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
kmeans.labels_
# Out:
# array([1, 0, 4, ..., 3, 1, 3], shape=(10695,), dtype=int32)

# %%
data['cluster']=kmeans.labels_

# %%
data.head()
# Out:
#    Gender  Ever_Married       Age  ...  Var_1  Segmentation  cluster
# 0       1             0 -1.282499  ...      3             3        1
# 1       0             1 -0.328606  ...      3             0        0
# 2       0             1  1.400325  ...      5             1        4
# 3       1             1  1.400325  ...      5             1        2
# 4       0             1 -0.209369  ...      5             0        3
#
# [5 rows x 11 columns]

# %%
# elbow method to find the best k
inertia=[] #within cluster sum of squares
for k in range(1,11):
    kmeans=KMeans(n_clusters=k,random_state=42)
    kmeans.fit(data)
    inertia.append(kmeans.inertia_)

# %%
inertia
# Out:
# [177415.78690977104,
#  122419.88967228058,
#  110784.67891611207,
#  85320.07199304053,
#  72464.47489306582,
#  68104.65023613631,
#  63401.62672736017,
#  62291.74234441841,
#  57859.48133453323,
#  56759.131327145275]

# %%
plt.figure(figsize=(5,3))
plt.plot(range(1,11),inertia,marker="o")
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.show()
