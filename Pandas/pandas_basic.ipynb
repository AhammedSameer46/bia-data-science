# %%
import  pandas as pd

# %%
students=pd.Series(["Ahammed","Ahad","sameer"])
print(students)
# Out:
# 0    Ahammed
# 1       Ahad
# 2     sameer
# dtype: str

# %%
data={
    "name":["Ahammed ","Ahad","sameer"],
    "Age":[21,20,52]
}  
df=pd.DataFrame(data)
print(df)
# Out:
#        name  Age
# 0  Ahammed    21
# 1      Ahad   20
# 2    sameer   52

# %%
data={
        "name":["rxr ","manu","jeef"],
    "Age":[21,20,52]
}  
df=pd.DataFrame(data)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 data={
#       2         "name":["rxr ","manu","jeef"],
#       3     "Age":[21,20,52]
#       4 }
# ----> 5 df=pd.DataFrame(data)
#       6 print(df)
#
# NameError: name 'pd' is not defined
