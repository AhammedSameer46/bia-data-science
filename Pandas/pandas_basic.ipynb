# %%
import  pandas as pd

# %%
students=pd.Series(["Ahammed","Ahad","sameer"])
print(students)
# Out:
# 0    Ahammed
# 1       Ahad
# 2     sameer
# dtype: str

# %%
data={
    "name":["Ahammed ","Ahad","sameer"],
    "Age":[21,20,52]
}  
df=pd.DataFrame(data)
print(df)
# Out:
#        name  Age
# 0  Ahammed    21
# 1      Ahad   20
# 2    sameer   52
